# %% [markdown]
# # 1.Cargando Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#lectura de datos en Python
train = pd.read_csv('./../data/train2.csv', encoding='latin-1')

# %%
train.head()
# Out:
#   ï»¿ref_area.label                                    indicator.label  \
# 0              Peru  Employment by sex and economic activity - ISIC...
# 1              Peru  Employment by sex and economic activity - ISIC...
# 2              Peru  Employment by sex and economic activity - ISIC...
# 3              Peru  Employment by sex and economic activity - ISIC...
# 4              Peru  Employment by sex and economic activity - ISIC...
#
#                         source.label   sex.label  \
# 0  HS - Encuesta Nacional de Hogares  Sex: Total
# 1  HS - Encuesta Nacional de Hogares  Sex: Total
# 2  HS - Encuesta Nacional de Hogares  Sex: Total
# 3  HS - Encuesta Nacional de Hogares  Sex: Total
# 4  HS - Encuesta Nacional de Hogares  Sex: Total
#
#                                       classif1.label  time  obs_value  \
# 0  Economic activity (ISIC-Rev.4), 2 digit level:...  2017  17479.817
# 1  Economic activity (ISIC-Rev.4), 2 digit level:...  2017   4441.899
# 2  Economic activity (ISIC-Rev.4), 2 digit level:...  2017     21.865
# 3  Economic activity (ISIC-Rev.4), 2 digit level:...  2017     98.687
# 4  Economic activity (ISIC-Rev.4), 2 digit level:...  2017      2.211
#
#   obs_status.label  note_indicator.label  \
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4       Unreliable                   NaN
#
#                                    note_source.label
# 0  Repository: ILO-STATISTICS - Micro data proces...
# 1  Repository: ILO-STATISTICS - Micro data proces...
# 2  Repository: ILO-STATISTICS - Micro data proces...
# 3  Repository: ILO-STATISTICS - Micro data proces...
# 4  Repository: ILO-STATISTICS - Micro data proces...

# %% [markdown]
# # 2.Explorando datos

# %%
#Columnas que tienen los datos
train.columns
# Out:
# Index(['ï»¿ref_area.label', 'indicator.label', 'source.label', 'sex.label',
#        'classif1.label', 'time', 'obs_value', 'obs_status.label',
#        'note_indicator.label', 'note_source.label'],
#       dtype='object')

# %%
#TAMAÑO DE DATOS
train.shape
# Out:
# (1041, 10)

# %%
#valores nulos
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ï»¿ref_area.label     1041 non-null   object
#  1   indicator.label       1041 non-null   object
#  2   source.label          1041 non-null   object
#  3   sex.label             1041 non-null   object
#  4   classif1.label        1041 non-null   object
#  5   time                  1041 non-null   int64
#  6   obs_value             945 non-null    float64
#  7   obs_status.label      244 non-null    object
#  8   note_indicator.label  0 non-null      float64
#  9   note_source.label     1041 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 81.5+ KB

# %%
# como se distribuyen las variables numéricas
train.describe()
# Out:
#               time     obs_value  note_indicator.label
# count  1041.000000    945.000000                   0.0
# mean   2018.497598    289.717168                   NaN
# std       1.114694   1416.825021                   NaN
# min    2017.000000      0.712000                   NaN
# 25%    2018.000000      9.576000                   NaN
# 50%    2018.000000     25.887000                   NaN
# 75%    2019.000000     94.656000                   NaN
# max    2020.000000  18049.074000                   NaN

# %%
# como se comportan las variables categóricas
train.describe(include=['O'])
# Out:
#        ï»¿ref_area.label                                    indicator.label  \
# count               1041                                               1041
# unique                 1                                                  1
# top                 Peru  Employment by sex and economic activity - ISIC...
# freq                1041                                               1041
#
#                              source.label   sex.label  \
# count                                1041        1041
# unique                                  1           3
# top     HS - Encuesta Nacional de Hogares  Sex: Total
# freq                                 1041         352
#
#                                            classif1.label obs_status.label  \
# count                                                1041              244
# unique                                                 89                1
# top     Economic activity (ISIC-Rev.4), 2 digit level:...       Unreliable
# freq                                                   12              244
#
#                                         note_source.label
# count                                                1041
# unique                                                  1
# top     Repository: ILO-STATISTICS - Micro data proces...
# freq                                                 1041

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ï»¿ref_area.label     1041 non-null   object
#  1   indicator.label       1041 non-null   object
#  2   source.label          1041 non-null   object
#  3   sex.label             1041 non-null   object
#  4   classif1.label        1041 non-null   object
#  5   time                  1041 non-null   int64
#  6   obs_value             945 non-null    float64
#  7   obs_status.label      244 non-null    object
#  8   note_indicator.label  0 non-null      float64
#  9   note_source.label     1041 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 81.5+ KB

# %%
#CANTIDAD DE DATOS NULOS POR COLUMNA
train.isnull().sum()
# Out:
# ï»¿ref_area.label          0
# indicator.label            0
# source.label               0
# sex.label                  0
# classif1.label             0
# time                       0
# obs_value                 96
# obs_status.label         797
# note_indicator.label    1041
# note_source.label          0
# dtype: int64

# %%
train.shape
# Out:
# (1041, 10)

# %%
train.columns
# Out:
# Index(['ï»¿ref_area.label', 'indicator.label', 'source.label', 'sex.label',
#        'classif1.label', 'time', 'obs_value', 'obs_status.label',
#        'note_indicator.label', 'note_source.label'],
#       dtype='object')

# %%
train.columns =[ 'Pais','Indicador','Fuente', 'Sexo','Clasificacion', 'Año','Cantidad','status','Filtro','Etiqueta']
train.columns
# Out:
# Index(['Pais', 'Indicador', 'Fuente', 'Sexo', 'Clasificacion', 'Año',
#        'Cantidad', 'status', 'Filtro', 'Etiqueta'],
#       dtype='object')

# %%
train
# Out:
#       Pais                                          Indicador  \
# 0     Peru  Employment by sex and economic activity - ISIC...
# 1     Peru  Employment by sex and economic activity - ISIC...
# 2     Peru  Employment by sex and economic activity - ISIC...
# 3     Peru  Employment by sex and economic activity - ISIC...
# 4     Peru  Employment by sex and economic activity - ISIC...
# ...    ...                                                ...
# 1036  Peru  Employment by sex and economic activity - ISIC...
# 1037  Peru  Employment by sex and economic activity - ISIC...
# 1038  Peru  Employment by sex and economic activity - ISIC...
# 1039  Peru  Employment by sex and economic activity - ISIC...
# 1040  Peru  Employment by sex and economic activity - ISIC...
#
#                                  Fuente         Sexo  \
# 0     HS - Encuesta Nacional de Hogares   Sex: Total
# 1     HS - Encuesta Nacional de Hogares   Sex: Total
# 2     HS - Encuesta Nacional de Hogares   Sex: Total
# 3     HS - Encuesta Nacional de Hogares   Sex: Total
# 4     HS - Encuesta Nacional de Hogares   Sex: Total
# ...                                 ...          ...
# 1036  HS - Encuesta Nacional de Hogares  Sex: Female
# 1037  HS - Encuesta Nacional de Hogares  Sex: Female
# 1038  HS - Encuesta Nacional de Hogares  Sex: Female
# 1039  HS - Encuesta Nacional de Hogares  Sex: Female
# 1040  HS - Encuesta Nacional de Hogares  Sex: Female
#
#                                           Clasificacion   Año   Cantidad  \
# 0     Economic activity (ISIC-Rev.4), 2 digit level:...  2017  17479.817
# 1     Economic activity (ISIC-Rev.4), 2 digit level:...  2017   4441.899
# 2     Economic activity (ISIC-Rev.4), 2 digit level:...  2017     21.865
# 3     Economic activity (ISIC-Rev.4), 2 digit level:...  2017     98.687
# 4     Economic activity (ISIC-Rev.4), 2 digit level:...  2017      2.211
# ...                                                 ...   ...        ...
# 1036  Economic activity (ISIC-Rev.4), 2 digit level:...  2020     19.962
# 1037  Economic activity (ISIC-Rev.4), 2 digit level:...  2020    149.950
# 1038  Economic activity (ISIC-Rev.4), 2 digit level:...  2020    220.138
# 1039  Economic activity (ISIC-Rev.4), 2 digit level:...  2020        NaN
# 1040  Economic activity (ISIC-Rev.4), 2 digit level:...  2020        NaN
#
#           status  Filtro                                           Etiqueta
# 0            NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 1            NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 2            NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 3            NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 4     Unreliable     NaN  Repository: ILO-STATISTICS - Micro data proces...
# ...          ...     ...                                                ...
# 1036         NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 1037         NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 1038         NaN     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 1039  Unreliable     NaN  Repository: ILO-STATISTICS - Micro data proces...
# 1040  Unreliable     NaN  Repository: ILO-STATISTICS - Micro data proces...
#
# [1041 rows x 10 columns]

# %%
train = train.dropna(how='all') #ELIMINAMOS FILAS QUE TENGAN TODOS SUS VALORES NULOS
train = train[train['Clasificacion'].notna()]#ELIMINAMOS FILAS QUE TENGAN VALOR NULO EN LA COLUMNA OCUPACIONES
train = train[train['Cantidad'].notna()]
train = train.drop(columns=['Indicador','Fuente' ,'status','Etiqueta'])#eliminamos columnas irrelevantes
train
# Out:
#       Pais         Sexo                                      Clasificacion  \
# 0     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 2     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 3     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 4     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# ...    ...          ...                                                ...
# 1034  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1035  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1036  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1037  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1038  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
#
#        Año   Cantidad  Filtro
# 0     2017  17479.817     NaN
# 1     2017   4441.899     NaN
# 2     2017     21.865     NaN
# 3     2017     98.687     NaN
# 4     2017      2.211     NaN
# ...    ...        ...     ...
# 1034  2020     11.406     NaN
# 1035  2020     24.282     NaN
# 1036  2020     19.962     NaN
# 1037  2020    149.950     NaN
# 1038  2020    220.138     NaN
#
# [945 rows x 6 columns]

# %%
train['Filtro'] = 0.0
train
# Out:
#       Pais         Sexo                                      Clasificacion  \
# 0     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 2     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 3     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 4     Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# ...    ...          ...                                                ...
# 1034  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1035  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1036  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1037  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 1038  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
#
#        Año   Cantidad  Filtro
# 0     2017  17479.817     0.0
# 1     2017   4441.899     0.0
# 2     2017     21.865     0.0
# 3     2017     98.687     0.0
# 4     2017      2.211     0.0
# ...    ...        ...     ...
# 1034  2020     11.406     0.0
# 1035  2020     24.282     0.0
# 1036  2020     19.962     0.0
# 1037  2020    149.950     0.0
# 1038  2020    220.138     0.0
#
# [945 rows x 6 columns]

# %%
train.isnull().sum()#no hay nulos
# Out:
# Pais             0
# Sexo             0
# Clasificacion    0
# Año              0
# Cantidad         0
# Filtro           0
# dtype: int64

# %%
train.columns
# Out:
# Index(['Pais', 'Sexo', 'Clasificacion', 'Año', 'Cantidad', 'Filtro'], dtype='object')

# %%
from textblob.classifiers import NaiveBayesClassifier

with open('data_entrenada.json', 'r') as fp: 
    clear=NaiveBayesClassifier(fp, format="json")  

i=0
for f in range(train.shape[0]):
    try:
        estado = clear.classify(train.Actividad_Economica[f]) 
        if (estado =="1"):      
            i = i + 1           
            train.Filtro[f]=1         

    except:
        Exception
print(i)
train=train[train["Filtro"]>0]
# Out:
# 0

# %%
train=train.sort_values("Clasificacion",False)
train
# Out:
# C:\Users\lenri\AppData\Local\Temp/ipykernel_16396/582062700.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only
#   train=train.sort_values("Clasificacion",False)
#      Pais         Sexo                                      Clasificacion  \
# 51   Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 486  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 574  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 225  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 663  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 312  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 748  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 401  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 138  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 835  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 921  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 837  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 576  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 923  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 403  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 750  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 665  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 488  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 314  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 53   Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 140  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 227  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 494  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 147  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 757  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 583  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 233  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 672  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 844  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 60   Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 410  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 929  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 321  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 758  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 61   Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 845  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 322  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 148  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 584  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 495  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 930  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 234  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 411  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 673  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 674  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 149  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 585  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 759  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 62   Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 412  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
# 846  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 235  Peru  Sex: Female  Economic activity (ISIC-Rev.4), 2 digit level:...
# 323  Peru   Sex: Total  Economic activity (ISIC-Rev.4), 2 digit level:...
# 931  Peru    Sex: Male  Economic activity (ISIC-Rev.4), 2 digit level:...
#
#       Año  Cantidad  Filtro
# 51   2017    16.165     1.0
# 486  2018     3.327     1.0
# 574  2019    19.860     1.0
# 225  2017     3.257     1.0
# 663  2019    13.799     1.0
# 312  2018    17.956     1.0
# 748  2019     6.062     1.0
# 401  2018    14.629     1.0
# 138  2017    12.908     1.0
# 835  2020    24.827     1.0
# 921  2020    18.942     1.0
# 837  2020    24.532     1.0
# 576  2019    29.895     1.0
# 923  2020    20.413     1.0
# 403  2018    26.828     1.0
# 750  2019     7.145     1.0
# 665  2019    22.750     1.0
# 488  2018     9.316     1.0
# 314  2018    36.144     1.0
# 53   2017    20.767     1.0
# 140  2017    17.145     1.0
# 227  2017     3.622     1.0
# 494  2018     5.838     1.0
# 147  2017     8.871     1.0
# 757  2019     7.790     1.0
# 583  2019    18.009     1.0
# 233  2017     4.916     1.0
# 672  2019    10.219     1.0
# 844  2020     9.604     1.0
# 60   2017    13.787     1.0
# 410  2018    12.491     1.0
# 929  2020     6.149     1.0
# 321  2018    18.329     1.0
# 758  2019    17.535     1.0
# 61   2017    49.831     1.0
# 845  2020    65.097     1.0
# 322  2018    65.326     1.0
# 148  2017    39.954     1.0
# 584  2019    68.124     1.0
# 495  2018    18.737     1.0
# 930  2020    49.639     1.0
# 234  2017     9.877     1.0
# 411  2018    46.589     1.0
# 673  2019    50.589     1.0
# 674  2019     5.530     1.0
# 149  2017     6.709     1.0
# 585  2019     8.300     1.0
# 759  2019     2.770     1.0
# 62   2017     9.224     1.0
# 412  2018     1.408     1.0
# 846  2020     5.520     1.0
# 235  2017     2.515     1.0
# 323  2018     2.868     1.0
# 931  2020     3.989     1.0

# %%
train.to_csv('data_filtrada1.csv', index=False) ##se exporta el dataframe a un csv
